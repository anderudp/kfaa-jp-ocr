# %%
# %cd /home/anderu/Workspaces/python_ws/kfaa-jp-ocr/yolov5
# Out:
# /home/anderu/Workspaces/python_ws/kfaa-jp-ocr/yolov5
# /home/anderu/Workspaces/python_ws/.venv/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# %pip install -qr requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import PIL
from PIL import Image

# %%
im_path = "/home/anderu/Workspaces/python_ws/kfaa-jp-ocr/test_ims/moguraya-bakemonogatari-p25.jpg"

# %%
im = Image.open(im_path).convert('L')

# %%
im.show()

# %%
im.save("./test.jpg")

# %%
# !python detect.py --weights ../best.pt --source ../test.png  --conf-thres 0.001 --hide-conf --save-txt --project "../"
# Out:
# detect: weights=['../best.pt'], source=../test.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.001, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=../, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=True, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-312-g1bcd17ee Python-3.11.9 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Ti Laptop GPU, 3898MiB)
#
# Fusing layers...
# Model summary: 157 layers, 12870706 parameters, 0 gradients, 34.4 GFLOPs
# Traceback (most recent call last):
#   File "/home/anderu/Workspaces/python_ws/kfaa-jp-ocr/yolov5/detect.py", line 312, in <module>
#     main(opt)
#   File "/home/anderu/Workspaces/python_ws/kfaa-jp-ocr/yolov5/detect.py", line 307, in main
#     run(**vars(opt))
# ...
