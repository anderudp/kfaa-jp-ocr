# %%
import os
import yaml
import cv2
from IPython.display import Image

# %%
home = os.environ['HOME']
chars = os.listdir(home + "/Storage/Datasets/ETL/ETL2")
chars = sorted(chars, key=lambda x: int(x, 16))

# %%
f = open("classes_inverse.yaml", "w")
f.write("names:\n")
for i in range(len(chars)):
    f.write(f"  \"{chars[i]}\": {i} # {chr(int(chars[i], 16))}\n")

# %%
with open("classes.yaml", 'r') as file:
    asd = yaml.safe_load(file)
asd
# Out:
# {'names': {0: '0x0021',
#   1: '0x0025',
#   2: '0x0030',
#   3: '0x0031',
#   4: '0x0032',
#   5: '0x0033',
#   6: '0x0034',
#   7: '0x0035',
#   8: '0x0036',
#   9: '0x0037',
#   10: '0x0038',
#   11: '0x0039',
#   12: '0x003f',
#   13: '0x0041',
#   14: '0x0042',
#   15: '0x0043',
#   16: '0x0044',
#   17: '0x0045',
#   18: '0x0046',
#   19: '0x0047',
#   20: '0x0048',
#   21: '0x0049',
#   22: '0x004a',
#   23: '0x004b',
#   24: '0x004c',
#   25: '0x004d',
#   26: '0x004e',
#   27: '0x004f',
#   28: '0x0050',
#   29: '0x0051',
#   30: '0x0052',
#   31: '0x0053',
#   32: '0x0054',
#   33: '0x0055',
#   34: '0x0056',
#   35: '0x0057',
#   36: '0x0058',
#   37: '0x0059',
#   38: '0x005a',
#   39: '0x007c',
#   40: '0x00d7',
#   41: '0x2016',
#   42: '0x3001',
#   43: '0x3002',
#   44: '0x3007',
#   45: '0x300e',
#   46: '0x300f',
#   47: '0x3010',
#   48: '0x3011',
#   49: '0x3042',
#   50: '0x3044',
#   51: '0x3046',
#   52: '0x3048',
#   53: '0x304a',
#   54: '0x304b',
# ...
